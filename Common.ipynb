# %% [markdown]
# <a href="https://colab.research.google.com/github/allenhu08/capstone/blob/main/Common.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/allenhu08/capstone.git || cd capstone && git pull
# Out:
# fatal: destination path 'capstone' already exists and is not an empty directory.
# Already up to date.

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('./capstone/datasets/rawdata_new.csv')
# Out:
#       id              date  total_agr_land  workforce  trees  arable_land  \
# 0      1  13.03.2019 10:59          4925.0    1.95406     79         3871
# 1      2  13.03.2019 11:08          2176.0    6.61310     12         1671
# 2      3  13.03.2019 11:37          2251.0    1.39384     31         1507
# 3      4  13.03.2019 13:54          2389.0    1.99523      3         1969
# 4      5  13.03.2019 14:18          3205.0    3.09942     39         1911
# ..   ...               ...             ...        ...    ...          ...
# 100  101  15.04.2019 21:22          1786.0    0.86598     32          719
# 101  102  02.05.2019 11:02           876.0    4.29667      0            0
# 102  103  03.05.2019 19:39          2995.0    2.96772     64          879
# 103  104  06.05.2019 11:32          6520.0    4.04098      0         4720
# 104  105  10.05.2019 08:36          4894.0    2.70479     30         3901
#
#      ley  perm_grass  perm_crops  prot_cult  ...  network  GHG_goal  env_goal  \
# ...
